# %% [markdown]
# # Good Morning Everyone
#
# ## Welcome to Final Session of Python Programming

# %% [markdown]
# ## Todays Objectives
# ### Data Visualization using Matplotlib

# %% [markdown]
# ## Creating Students Data

# %% [markdown]
# rollnumbers = year + collegecode + universitycode + branchcode + rollNO
#
# 100 Students
#
# 20APPY0501 - 100

# %%
roll = '20APPY05'
for i in range(1,101,1):
    if i < 10:
        print(roll + str(0) +str(i))
    else:
        print(roll + str(i))
# Out:
# 20APPY0501
# 20APPY0502
# 20APPY0503
# 20APPY0504
# 20APPY0505
# 20APPY0506
# 20APPY0507
# 20APPY0508
# 20APPY0509
# 20APPY0510
# 20APPY0511
# 20APPY0512
# 20APPY0513
# 20APPY0514
# 20APPY0515
# 20APPY0516
# 20APPY0517
# 20APPY0518
# 20APPY0519
# 20APPY0520
# 20APPY0521
# 20APPY0522
# 20APPY0523
# 20APPY0524
# 20APPY0525
# 20APPY0526
# 20APPY0527
# 20APPY0528
# 20APPY0529
# 20APPY0530
# 20APPY0531
# 20APPY0532
# 20APPY0533
# 20APPY0534
# 20APPY0535
# 20APPY0536
# 20APPY0537
# 20APPY0538
# 20APPY0539
# 20APPY0540
# 20APPY0541
# 20APPY0542
# 20APPY0543
# 20APPY0544
# 20APPY0545
# 20APPY0546
# 20APPY0547
# 20APPY0548
# 20APPY0549
# 20APPY0550
# 20APPY0551
# 20APPY0552
# 20APPY0553
# 20APPY0554
# 20APPY0555
# 20APPY0556
# 20APPY0557
# 20APPY0558
# 20APPY0559
# 20APPY0560
# 20APPY0561
# 20APPY0562
# 20APPY0563
# 20APPY0564
# 20APPY0565
# 20APPY0566
# 20APPY0567
# 20APPY0568
# 20APPY0569
# 20APPY0570
# 20APPY0571
# 20APPY0572
# 20APPY0573
# 20APPY0574
# 20APPY0575
# 20APPY0576
# ...

# %%
roll = '20APPY05'
rollNumber = [roll + str(0) +str(num) if num<10 else roll + str(num) for num in range(1,101,1)]
print(rollNumber)
# Out:
# ['20APPY0501', '20APPY0502', '20APPY0503', '20APPY0504', '20APPY0505', '20APPY0506', '20APPY0507', '20APPY0508', '20APPY0509', '20APPY0510', '20APPY0511', '20APPY0512', '20APPY0513', '20APPY0514', '20APPY0515', '20APPY0516', '20APPY0517', '20APPY0518', '20APPY0519', '20APPY0520', '20APPY0521', '20APPY0522', '20APPY0523', '20APPY0524', '20APPY0525', '20APPY0526', '20APPY0527', '20APPY0528', '20APPY0529', '20APPY0530', '20APPY0531', '20APPY0532', '20APPY0533', '20APPY0534', '20APPY0535', '20APPY0536', '20APPY0537', '20APPY0538', '20APPY0539', '20APPY0540', '20APPY0541', '20APPY0542', '20APPY0543', '20APPY0544', '20APPY0545', '20APPY0546', '20APPY0547', '20APPY0548', '20APPY0549', '20APPY0550', '20APPY0551', '20APPY0552', '20APPY0553', '20APPY0554', '20APPY0555', '20APPY0556', '20APPY0557', '20APPY0558', '20APPY0559', '20APPY0560', '20APPY0561', '20APPY0562', '20APPY0563', '20APPY0564', '20APPY0565', '20APPY0566', '20APPY0567', '20APPY0568', '20APPY0569', '20APPY0570', '20APPY0571', '20
# ...

# %%
import numpy as np

np.random.randint(1,100)
# Out:
# 5

# %%
C = [np.random.randint(0,100) for i in range(1,101)]
Python = [np.random.randint(0,100) for i in range(1,101)]
Java = [np.random.randint(0,100) for i in range(1,101)]
Pandas = [np.random.randint(0,100) for i in range(1,101)]
subjects = ['C', 'Python', 'Java', 'Pandas']
print(C)
# Out:
# [98, 61, 42, 39, 8, 38, 49, 86, 52, 24, 19, 76, 92, 17, 10, 10, 13, 79, 16, 56, 11, 68, 96, 97, 13, 2, 39, 99, 31, 64, 65, 16, 11, 56, 79, 46, 90, 77, 21, 82, 73, 64, 15, 0, 74, 67, 23, 83, 98, 61, 98, 51, 51, 85, 73, 83, 72, 72, 2, 81, 9, 36, 15, 4, 3, 87, 3, 24, 77, 35, 45, 17, 5, 56, 35, 44, 73, 77, 2, 55, 6, 48, 81, 78, 70, 99, 17, 16, 62, 5, 89, 9, 93, 72, 81, 88, 81, 84, 32, 62]

# %% [markdown]
# Total_marks = C + Python + Java + Pandas

# %%
C = np.array(C)
Python = np.array(Python)
Java = np.array(Java)
Pandas = np.array(Pandas)

# %%
Total_marks = C + Python + Java + Pandas
print(Total_marks)
# Out:
# [194 243 134 172 153 277 156 256 204 106 151 272 247 144 243 177 250 232
#  252 211 106 190 185 183 208 254 226 132 254 230 150 304 215  89 134 173
#  182 204 135 270 245 165 174 114 222 217 243 172 244 103 297 239 213 175
#  329 170 230 270 240 157 190 164 155 214 208 174 270 166 174 281 189 156
#  199 236 128 246 154 260 148 161 275 249 176 177 186 202 143 173 154 117
#  237 224 249  49 256 200 178 105 216 237]

# %%
percentage = (Total_marks / (len(subjects) * 100)) * 100
print(percentage)
# Out:
# [48.5  60.75 33.5  43.   38.25 69.25 39.   64.   51.   26.5  37.75 68.
#  61.75 36.   60.75 44.25 62.5  58.   63.   52.75 26.5  47.5  46.25 45.75
#  52.   63.5  56.5  33.   63.5  57.5  37.5  76.   53.75 22.25 33.5  43.25
#  45.5  51.   33.75 67.5  61.25 41.25 43.5  28.5  55.5  54.25 60.75 43.
#  61.   25.75 74.25 59.75 53.25 43.75 82.25 42.5  57.5  67.5  60.   39.25
#  47.5  41.   38.75 53.5  52.   43.5  67.5  41.5  43.5  70.25 47.25 39.
#  49.75 59.   32.   61.5  38.5  65.   37.   40.25 68.75 62.25 44.   44.25
#  46.5  50.5  35.75 43.25 38.5  29.25 59.25 56.   62.25 12.25 64.   50.
#  44.5  26.25 54.   59.25]

# %%
import pandas as pd

Student_report = pd.DataFrame([rollNumber, C, Python, Java, Pandas, Total_marks, percentage]).T

# %%
Student_report
# Out:
#               0   1   2   3   4    5      6
# 0    20APPY0501  98  33  43  38  194   48.5
# 1    20APPY0502  61  11  28  13  243  60.75
# 2    20APPY0503  42  25  45  78  134   33.5
# 3    20APPY0504  39  31  93  36  172     43
# 4    20APPY0505   8  37   7  42  153  38.25
# 5    20APPY0506  38  34  34  85  277  69.25
# 6    20APPY0507  49  95  21   5  156     39
# 7    20APPY0508  86  72  21  81  256     64
# 8    20APPY0509  52  79  63  31  204     51
# 9    20APPY0510  24  29  31  93  106   26.5
# 10   20APPY0511  19  48  58   4  151  37.75
# 11   20APPY0512  76  20  16  94  272     68
# 12   20APPY0513  92  38   4  43  247  61.75
# 13   20APPY0514  17  32  11  23  144     36
# 14   20APPY0515  10  52   1  46  243  60.75
# 15   20APPY0516  10   5  18  35  177  44.25
# 16   20APPY0517  13  80  67  90  250   62.5
# 17   20APPY0518  79  98  61  79  232     58
# 18   20APPY0519  16  56  14  44  252     63
# 19   20APPY0520  56  48  12  80  211  52.75
# ...

# %%
Student_report.columns
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
Student_report.columns = ['RollNumber', 'C', 'Python', 'Java', 'Pandas', 'TotalMarks', 'Percentage']

# %%
Student_report
# Out:
#      RollNumber   C Python Java Pandas TotalMarks Percentage
# 0    20APPY0501  98     33   43     38        194       48.5
# 1    20APPY0502  61     11   28     13        243      60.75
# 2    20APPY0503  42     25   45     78        134       33.5
# 3    20APPY0504  39     31   93     36        172         43
# 4    20APPY0505   8     37    7     42        153      38.25
# 5    20APPY0506  38     34   34     85        277      69.25
# 6    20APPY0507  49     95   21      5        156         39
# 7    20APPY0508  86     72   21     81        256         64
# 8    20APPY0509  52     79   63     31        204         51
# 9    20APPY0510  24     29   31     93        106       26.5
# 10   20APPY0511  19     48   58      4        151      37.75
# 11   20APPY0512  76     20   16     94        272         68
# 12   20APPY0513  92     38    4     43        247      61.75
# 13   20APPY0514  17     32   11     23        144         36
# ...

# %%
Student_report.head()
# Out:
#    RollNumber   C Python Java Pandas TotalMarks Percentage
# 0  20APPY0501  98     33   43     38        194       48.5
# 1  20APPY0502  61     11   28     13        243      60.75
# 2  20APPY0503  42     25   45     78        134       33.5
# 3  20APPY0504  39     31   93     36        172         43
# 4  20APPY0505   8     37    7     42        153      38.25

# %%
Student_report.tail()
# Out:
#      RollNumber   C Python Java Pandas TotalMarks Percentage
# 95   20APPY0596  88     15   54     46        200         50
# 96   20APPY0597  81     74   18     63        178       44.5
# 97   20APPY0598  84     83    7      6        105      26.25
# 98   20APPY0599  32     64   91     65        216         54
# 99  20APPY05100  62     19   39     96        237      59.25

# %% [markdown]
# ## Line Plot
# ## Scatter Plot
# ## Hitogram
# ## Bar Graph
# ## Pie Chart
# ## Box Plot

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](P1.png)

# %% [markdown]
# Matplotlib package was implemented John Hunter
#
# ## [Matplotlib Home Page](https://matplotlib.org/)

# %%
X = [1, 3, 5, 7, 9]
Y = [2,4,6,8,10]
plt.figure(figsize=(10, 5)) # width, height
plt.plot(X,Y, color = 'r')
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("X vs Y Line Plot")

plt.show()

# %%
X = np.arange(-50, 50)
Y = X ** 2

plt.plot(X,Y)

# %%
deg  = np.arange(0,361,15)
X = np.radians(deg)
Y = np.sin(X)

plt.plot(X,Y)
plt.xlabel("Deg in radians")
plt.ylabel("Sin values")
plt.title("Sin Graph from 0 deg to 360 deg")
plt.grid()

# %%
deg  = np.arange(0,361,15)
X = np.radians(deg)
Y = np.cos(X)

plt.plot(X,Y)
plt.xlabel("Deg in radians")
plt.ylabel("Cosine values")
plt.title("Cosine Graph from 0 deg to 360 deg")
plt.grid()

# %%
deg  = np.arange(0,361,15)
sinx = np.radians(deg)
siny = np.sin(X)
cosx = sinx
cosy = np.cos(X)
plt.plot(sinx,siny, label = 'Sin')
plt.plot(cosx,cosy, label = 'Cos')
plt.xlabel("Deg in radians")
plt.ylabel("Sin values")
plt.legend?
plt.title("Sin Graph from 0 deg to 360 deg")
plt.grid()

# %%
deg  = np.arange(0,361,15)
sinx = np.radians(deg)
siny = np.sin(X)
cosx = sinx
cosy = np.cos(X)
plt.plot(sinx,siny)
plt.xlabel("Deg in radians")
plt.ylabel("Sin values")
plt.title("Sin Graph from 0 deg to 360 deg")
plt.grid()
plt.show()
plt.plot(cosx,cosy, linestyle = '-.')
plt.xlabel("Deg in radians")
plt.ylabel("cosine values")
plt.title("cosine Graph from 0 deg to 360 deg")
plt.grid()
plt.show()

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
plt.plot(cosx,cosy, linewidth = 2.5, marker = 'o')
plt.xlabel("Deg in radians")
plt.ylabel("cosine values")
plt.title("cosine Graph from 0 deg to 360 deg")
plt.grid()
plt.show()

# %%
import matplotlib
help(matplotlib)
# Out:
# C:\Users\Jesus\Anaconda3\lib\site-packages\matplotlib\__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# C:\Users\Jesus\Anaconda3\lib\site-packages\matplotlib\__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# Help on package matplotlib:
#
# NAME
#     matplotlib - This is an object-oriented plotting library.
#
# DESCRIPTION
#     A procedural interface is provided by the companion pyplot module,
#     which may be imported directly, e.g.::
#
#         import matplotlib.pyplot as plt
#
#     or using ipython::
#
#         ipython
#
#     at your terminal, followed by::
#
#         In [1]: %matplotlib
# ...

# %% [markdown]
# ![image.png](P2.png)

# %%
X = Student_report['C']
Y = Student_report['Python']
plt.scatter(X,Y)

# %%
plt.figure(figsize=(15,10))

plt.scatter(Student_report['RollNumber'], Student_report['C'])

# %% [markdown]
# ## 10 min Break 11:00 11:10

# %% [markdown]
# #### HackerEarth --> will give demo
# #### 2:00 to : 3:00PM
# #### mail before 10min
# #### 20marks MCQs and 2 problem
# #### Certificate will issued based on exam & attendance

# %%
import pandas as pd

itc_df =  pd.read_csv('https://raw.githubusercontent.com/AP-Skill-Development-Corporation/Python-FDP-TEAM-1-1/master/Day11_30May2020/ITC.csv')
itc_df.head()
# Out:
#    Unnamed: 0 Symbol Series        Date  Prev Close  Open Price  High Price  \
# 0           0    ITC     EQ  2017-05-15      274.95      275.90      278.90
# 1           1    ITC     EQ  2017-05-16      277.95      278.50      284.30
# 2           2    ITC     EQ  2017-05-17      283.45      284.10      284.40
# 3           3    ITC     EQ  2017-05-18      281.65      278.00      281.05
# 4           4    ITC     EQ  2017-05-19      277.90      282.25      295.65
#
#    Low Price  Last Price  Close Price  ...  Total Traded Quantity  \
# 0     275.50      278.50       277.95  ...                5462855
# 1     278.00      283.00       283.45  ...               11204308
# 2     279.25      281.50       281.65  ...                8297700
# 3     277.05      277.65       277.90  ...                7924261
# 4     281.95      286.40       286.20  ...               35724128
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %%
import pandas as pd

itc_df =  pd.read_csv('https://raw.githubusercontent.com/AP-Skill-Development-Corporation/Python-FDP-TEAM-1-1/master/Day11_30May2020/ITC.csv', index_col=0)
itc_df.head()
# Out:
#   Symbol Series        Date  Prev Close  Open Price  High Price  Low Price  \
# 0    ITC     EQ  2017-05-15      274.95      275.90      278.90     275.50
# 1    ITC     EQ  2017-05-16      277.95      278.50      284.30     278.00
# 2    ITC     EQ  2017-05-17      283.45      284.10      284.40     279.25
# 3    ITC     EQ  2017-05-18      281.65      278.00      281.05     277.05
# 4    ITC     EQ  2017-05-19      277.90      282.25      295.65     281.95
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      278.50       277.95         277.78                5462855
# 1      283.00       283.45         280.93               11204308
# 2      281.50       281.65         281.56                8297700
# 3      277.65       277.90         278.49                7924261
# 4      286.40       286.20         290.08               35724128
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %%
itc_df.columns
# Out:
# Index(['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price',
#        'Low Price', 'Last Price', 'Close Price', 'Average Price',
#        'Total Traded Quantity', 'Turnover', 'No. of Trades', 'Deliverable Qty',
#        '% Dly Qt to Traded Qty', 'Month', 'Year', 'VWAP', 'Day_Perc_Change',
#        'Trend'],
#       dtype='object')

# %%
itc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 494 entries, 0 to 495
# Data columns (total 20 columns):
# Symbol                    494 non-null object
# Series                    494 non-null object
# Date                      494 non-null object
# Prev Close                494 non-null float64
# Open Price                494 non-null float64
# High Price                494 non-null float64
# Low Price                 494 non-null float64
# Last Price                494 non-null float64
# Close Price               494 non-null float64
# Average Price             494 non-null float64
# Total Traded Quantity     494 non-null int64
# Turnover                  494 non-null float64
# No. of Trades             494 non-null int64
# Deliverable Qty           494 non-null int64
# % Dly Qt to Traded Qty    494 non-null float64
# Month                     494 non-null int64
# Year                      494 non-null int64
# VWAP                      494 non-null float64
# ...

# %%
itc_df['Date'] = itc_df.Date.astype('datetime64')

# %%
x = itc_df['Close Price']
y = itc_df['Date']
plt.figure(figsize=(25,10))
plt.scatter(y,x)
plt.plot(y,x)
# Out:
# C:\Users\Jesus\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Histogram
#
# it is an 1D plot it is to plot the frequency of the varaiabe in that array

# %%
plt.hist(itc_df['Series'])
plt.show()

# %%
help(plt.bar)
# Out:
# Help on function bar in module matplotlib.pyplot:
#
# bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)
#     Make a bar plot.
#
#     The bars are positioned at *x* with the given *align*\ment. Their
#     dimensions are given by *width* and *height*. The vertical baseline
#     is *bottom* (default 0).
#
#     Each of *x*, *height*, *width*, and *bottom* may either be a scalar
#     applying to all bars, or it may be a sequence of length N providing a
#     separate value for each bar.
#
#     Parameters
#     ----------
#     x : sequence of scalars
#         The x coordinates of the bars. See also *align* for the
#         alignment of the bars to the coordinates.
#
#     height : scalar or sequence of scalars
#         The height(s) of the bars.
#
#     width : scalar or array-like, optional
#         The width(s) of the bars (default: 0.8).
#
#     bottom : scalar or array-like, optional
#         The y coordinate(s) of the bars bases (default: 0).
# ...

# %%
plt.bar(Student_report['C'], height = 5)
# Out:
# <BarContainer object of 100 artists>

# %%
x = [1,2,3,4,5]
plt.pie(x, labels=x, radius=2, shadow=True)
plt.show()

# %%
help(plt.pie)
# Out:
# Help on function pie in module matplotlib.pyplot:
#
# pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=None, radius=None, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, data=None)
#     Plot a pie chart.
#
#     Make a pie chart of array *x*.  The fractional area of each wedge is
#     given by ``x/sum(x)``.  If ``sum(x) < 1``, then the values of *x* give
#     the fractional area directly and the array will not be normalized. The
#     resulting pie will have an empty wedge of size ``1 - sum(x)``.
#
#     The wedges are plotted counterclockwise, by default starting from the
#     x-axis.
#
#     Parameters
#     ----------
#     x : array-like
#         The wedge sizes.
#
#     explode : array-like, optional, default: None
#         If not *None*, is a ``len(x)`` array which specifies the fraction
#         of the radius with which to offset each wedge.
#
# ...

# %%
x = np.arange(0, 10, 0.005)
y = np.exp(-x/2.) * np.sin(2*np.pi*x)

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_xlim(0, 10)
ax.set_ylim(-1, 1)

plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,5,1)
plt.plot([1,2,3,4],[2,4,6,8])
plt.subplot(1,5,3)
plt.plot([1,2,3,4],[2,4,6,8])
plt.subplot(1,5,5)
plt.plot([1,2,3,4],[2,4,6,8])

# %%
plt.figure(figsize=(25,10))
plt.stem(itc_df['Day_Perc_Change'], label='Day_Perc_Change')

plt.legend()
plt.grid()
plt.show()

# %%
Student_report.to_csv("Student_report.csv")

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 7866-1790
#
#  Directory of C:\Users\Jesus\Desktop\Python FDP
#
# 30-May-20  12:06 PM    <DIR>          .
# 30-May-20  12:06 PM    <DIR>          ..
# 30-May-20  09:34 AM    <DIR>          .ipynb_checkpoints
# 30-May-20  12:06 PM         2,051,150 Day11.ipynb
# 23-May-20  08:28 AM             1,628 Day6.ipynb
# 30-May-20  11:11 AM    <DIR>          Python-FDP-TEAM-1-1
# 30-May-20  12:06 PM             3,821 Student_report.csv
# 25-May-20  09:02 PM           151,939 Summer_FDPS Attendance(upto 23-05-2020).pdf
#                4 File(s)      2,208,538 bytes
#                4 Dir(s)  141,689,012,224 bytes free

# %% [markdown]
# [Pandas](https://pandas.pydata.org/)

# %%
import seaborn as sns
# Out:
# C:\Users\Jesus\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Jesus\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Jesus\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Jesus\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# ...

# %%
s = 'abab'
print(s[::-1])
# Out:
# baba
